# %% [markdown]
# rethink log return, log and ln in numpy

# %% [markdown]
# # IMPORTS

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import imports_and_functions as fn
from imports_and_functions.packages import *

# %matplotlib inline
mpl.rcParams['figure.facecolor'] = '#232323'

# %% [markdown]
# # DATA

# %%
# leading data
df = pd.read_csv('./data/zillow_raw_2021.csv')

# %%
df.dtypes
# Out:
# RegionID        int64
# SizeRank        int64
# RegionName      int64
# RegionType     object
# StateName      object
#                ...
# 2020-12-31    float64
# 2021-01-31    float64
# 2021-02-28    float64
# 2021-03-31    float64
# 2021-04-30    float64
# Length: 313, dtype: object

# %%
# display dataset
df
# Out:
#        RegionID  SizeRank  RegionName  ... 2021-02-28 2021-03-31 2021-04-30
# 0         61639         0       10025  ...  1092196.0  1104487.0  1121360.0
# 1         84654         1       60657  ...   515983.0   517482.0   519569.0
# 2         61637         2       10023  ...  1120821.0  1118048.0  1120428.0
# 3         91982         3       77494  ...   365462.0   370763.0   376914.0
# 4         84616         4       60614  ...   656818.0   659416.0   662782.0
# ...         ...       ...         ...  ...        ...        ...        ...
# 30837     87060     34430       66045  ...   225272.0   229287.0   233174.0
# 30838     90986     34430       75599  ...    49377.0    49610.0    50222.0
# 30839     58379     34430        1470  ...   399243.0   398659.0   401526.0
# 30840     58117     35187         822  ...   171867.0   171381.0   172291.0
# 30841     58110     35187         801  ...    38316.0    37639.0    36916.0
#
# [30842 rows x 313 columns]

# %%
# column expaliner
#####

# %%
# information
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30842 entries, 0 to 30841
# Columns: 313 entries, RegionID to 2021-04-30
# dtypes: float64(304), int64(3), object(6)
# memory usage: 73.7+ MB
#    RegionID  SizeRank  RegionName  ... 2021-02-28 2021-03-31 2021-04-30
# 0     61639         0       10025  ...  1092196.0  1104487.0  1121360.0
# 1     84654         1       60657  ...   515983.0   517482.0   519569.0
# 2     61637         2       10023  ...  1120821.0  1118048.0  1120428.0
# 3     91982         3       77494  ...   365462.0   370763.0   376914.0
# 4     84616         4       60614  ...   656818.0   659416.0   662782.0
#
# [5 rows x 313 columns]

# %%
## selecting NY zipcodes
df_ny = df.loc[(df['State'] == 'NY')
               & (df['CountyName'] == 'Queens County')].reset_index()
df_ny.drop(['index'], axis=1, inplace=True)
df_ny
# Out:
#     RegionID  SizeRank  RegionName  ... 2021-02-28 2021-03-31 2021-04-30
# 0      62087        21       11375  ...   421097.0   416426.0   411762.0
# 1      62088       110       11377  ...   434951.0   433844.0   435544.0
# 2      62067       122       11355  ...   466919.0   465487.0   464428.0
# 3      62093       167       11385  ...   703008.0   704874.0   707296.0
# 4      62085       184       11373  ...   413289.0   415127.0   416809.0
# 5      62084       279       11372  ...   390607.0   388914.0   389908.0
# 6      62004       393       11101  ...   833444.0   827952.0   822370.0
# 7      62080       496       11368  ...   406164.0   404570.0   403652.0
# 8      62066       581       11354  ...   416733.0   414523.0   411965.0
# 9      62086       732       11374  ...   414567.0   413708.0   412868.0
# 10     62120       858       11434  ...   415070.0   414574.0   414619.0
# 11     62179       947       11691  ...   556678.0   558419.0   560278.0
# 12     62118      1271       11432  ...   652898.0   653655.0   655697.0
# 13     62121      1713       11435  ...   376961.0   378580.0   378927.0
# 14     62006      2121       11103  ...   752601.0   751708.0   751877.0
# 15     62077      2154       11365  ...   705044.0   705832.0   706928.0
# 16     62079      2222       11367  ...   417844.0   417757.0   418022.0
# 17     62069      2809       11357  ...   820842.0   821812.0   822467.0
# 18     62076      3171       11364  ...   510305.0   509562.0   508134.0
# 19     62070      3506       11358  ...   897735.0   897941.0   897168.0
# 20     62007      3574       11104  ...   466181.0   467021.0   464044.0
# 21     62090      4200       11379  ...   763210.0   764520.0   766161.0
# 22     62099      4385       11413  ...   575442.0   577542.0   581338.0
# 23     62106      4719       11420  ...   600657.0   602680.0   604603.0
# 24     62100      4821       11414  ...   506686.0   507868.0   509471.0
# 25     62098      5130       11412  ...   575170.0   577937.0   581654.0
# 26     62073      5133       11361  ...   795332.0   795355.0   795151.0
# 27     62089      5391       11378  ...   737800.0   737990.0   738171.0
# 28     62107      5414       11421  ...   606259.0   607544.0   607973.0
# 29     62105      5538       11419  ...   612966.0   616095.0   620214.0
# 30     62119      5589       11433  ...   551655.0   554616.0   557119.0
# 31     62072      5676       11360  ...   499535.0   497718.0   496283.0
# 32     62104      5756       11418  ...   607392.0   609746.0   612122.0
# 33     62101      5769       11415  ...   310914.0   304934.0   297538.0
# 34     62109      6259       11423  ...   625767.0   630411.0   638006.0
# 35     62081      6436       11369  ...   696911.0   701237.0   707477.0
# 36     62182      6529       11694  ...   640819.0   644862.0   648065.0
# 37     62108      6570       11422  ...   572342.0   571554.0   572027.0
# 38     62103      6841       11417  ...   612457.0   615680.0   619167.0
# 39     62113      6886       11427  ...   647574.0   651496.0   657234.0
# 40     62180      7098       11692  ...   266741.0   272745.0   275388.0
# 41     62082      7324       11370  ...   715316.0   715999.0   715961.0
# 42     62068      7633       11356  ...   728028.0   730516.0   733839.0
# 43     62115      7895       11429  ...   577540.0   580048.0   583710.0
# 44     62074      8062       11362  ...   591694.0   591611.0   591892.0
# 45     62097      8120       11411  ...   568897.0   568245.0   568945.0
# 46     62112      8198       11426  ...   652363.0   655331.0   657969.0
# 47     62114      8554       11428  ...   611535.0   616593.0   623049.0
# 48     62181      8812       11693  ...   350591.0   355157.0   356097.0
# 49     61979      8912       11004  ...   400391.0   405799.0   409080.0
# 50     62102      9277       11416  ...   609687.0   612198.0   614847.0
# 51     62122      9306       11436  ...   532509.0   534761.0   535380.0
# 52     62078      9616       11366  ...   883587.0   882933.0   882687.0
# 53     62075     12001       11363  ...   932673.0   931076.0   928875.0
# 54     62116     25178       11430  ...   642995.0   641942.0   642980.0
#
# [55 rows x 313 columns]

# %%
df_ny.drop(columns=['RegionID', 'SizeRank', 'RegionType', 'StateName'],
           inplace=True)

# %%
df_ny_reshaped = fn.melt_data(df_ny)
df_ny_reshaped
# Out:
#        RegionName State      City  ...     CountyName       date     value
# 0           11375    NY  New York  ...  Queens County 1996-01-31  129189.0
# 1           11377    NY  New York  ...  Queens County 1996-01-31  111191.0
# 2           11355    NY  New York  ...  Queens County 1996-01-31  120873.0
# 3           11385    NY  New York  ...  Queens County 1996-01-31  215700.0
# 4           11373    NY  New York  ...  Queens County 1996-01-31  114715.0
# ...           ...   ...       ...  ...            ...        ...       ...
# 16715       11416    NY  New York  ...  Queens County 2021-04-30  614847.0
# 16716       11436    NY  New York  ...  Queens County 2021-04-30  535380.0
# 16717       11366    NY  New York  ...  Queens County 2021-04-30  882687.0
# 16718       11363    NY  New York  ...  Queens County 2021-04-30  928875.0
# 16719       11430    NY  New York  ...  Queens County 2021-04-30  642980.0
#
# [16720 rows x 7 columns]

# %%
df_ny_reshaped.dtypes
# Out:
# RegionName             int64
# State                 object
# City                  object
# Metro                 object
# CountyName            object
# date          datetime64[ns]
# value                float64
# dtype: object

# %%
df_ny_reshaped['RegionName'] = df_ny_reshaped['RegionName'].astype('str')
df_ny_reshaped.set_index('date', inplace=True)

# %%
df_ny_reshaped.dtypes
# Out:
# RegionName     object
# State          object
# City           object
# Metro          object
# CountyName     object
# value         float64
# dtype: object

# %%
df_ny_reshaped
# Out:
#            RegionName State  ...     CountyName     value
# date                         ...
# 1996-01-31      11375    NY  ...  Queens County  129189.0
# 1996-01-31      11377    NY  ...  Queens County  111191.0
# 1996-01-31      11355    NY  ...  Queens County  120873.0
# 1996-01-31      11385    NY  ...  Queens County  215700.0
# 1996-01-31      11373    NY  ...  Queens County  114715.0
# ...               ...   ...  ...            ...       ...
# 2021-04-30      11416    NY  ...  Queens County  614847.0
# 2021-04-30      11436    NY  ...  Queens County  535380.0
# 2021-04-30      11366    NY  ...  Queens County  882687.0
# 2021-04-30      11363    NY  ...  Queens County  928875.0
# 2021-04-30      11430    NY  ...  Queens County  642980.0
#
# [16720 rows x 6 columns]

# %% [markdown]
# # EDA

# %% [markdown]
# # MODEL

# %%
# list of all zipcodes
zipcode_list = df_ny_reshaped['RegionName'].unique().tolist()
print('Total zipcodes: ', len(zipcode_list))

# converting to dict
TS = {}
for zipcode in zipcode_list:
    temp_df = df_ny_reshaped.groupby('RegionName').get_group(
        zipcode).sort_index()['value']
    TS[zipcode] = temp_df

# sanity check
print('Keys in the dict: ', len(TS.keys()))
print('All zipcodes accounted for: ', len(zipcode_list) == len(TS.keys()))
# Out:
# Total zipcodes:  55
# Keys in the dict:  55
# All zipcodes accounted for:  True

# %%
# converting to pandas.DataFrame
ts_df = pd.DataFrame(TS)
ts_df
# Out:
#                11375     11377     11355  ...     11366     11363     11430
# date                                      ...
# 1996-01-31  129189.0  111191.0  120873.0  ...  227326.0  346968.0  253175.0
# 1996-02-29  128476.0  110784.0  120431.0  ...  227169.0  347413.0  252204.0
# 1996-03-31  128105.0  110823.0  120228.0  ...  226699.0  348278.0  251766.0
# 1996-04-30  127360.0  110714.0  119757.0  ...  225982.0  349253.0  251324.0
# 1996-05-31  127055.0  110794.0  119493.0  ...  225593.0  350497.0  251464.0
# ...              ...       ...       ...  ...       ...       ...       ...
# 2020-12-31  431259.0  432383.0  471009.0  ...  883397.0  934384.0  642500.0
# 2021-01-31  427765.0  434379.0  469184.0  ...  884268.0  934303.0  643663.0
# 2021-02-28  421097.0  434951.0  466919.0  ...  883587.0  932673.0  642995.0
# 2021-03-31  416426.0  433844.0  465487.0  ...  882933.0  931076.0  641942.0
# 2021-04-30  411762.0  435544.0  464428.0  ...  882687.0  928875.0  642980.0
#
# [304 rows x 55 columns]

# %%
print(ts_df.index.freq)
# Out:
# None

# %%
ts_df.index.freq = 'M'

# %%
ts_df.index.freq

# %% [markdown]
# ## Model on test Zipcode

# %%
print(zipcode_list)
# Out:
# ['11375', '11377', '11355', '11385', '11373', '11372', '11101', '11368', '11354', '11374', '11434', '11691', '11432', '11435', '11103', '11365', '11367', '11357', '11364', '11358', '11104', '11379', '11413', '11420', '11414', '11412', '11361', '11378', '11421', '11419', '11433', '11360', '11418', '11415', '11423', '11369', '11694', '11422', '11417', '11427', '11692', '11370', '11356', '11429', '11362', '11411', '11426', '11428', '11693', '11004', '11416', '11436', '11366', '11363', '11430']

# %%
# testing one zipcode
zipcode = random.choice(zipcode_list)

# %%
print('\033[1m \033[91m' +
      f"""Selected Zipcode : {ts_df[zipcode].name}""")
ts_df[zipcode]
# Out:
#  Selected Zipcode : 11385
# date
# 1996-01-31    215700.0
# 1996-02-29    214560.0
# 1996-03-31    214290.0
# 1996-04-30    213097.0
# 1996-05-31    212966.0
#                 ...
# 2020-12-31    700433.0
# 2021-01-31    702276.0
# 2021-02-28    703008.0
# 2021-03-31    704874.0
# 2021-04-30    707296.0
# Freq: M, Name: 11385, Length: 304, dtype: float64

# %%
# timeline
ts_df[zipcode].plot(
    figsize=(15, 5),
    legend=0,
    color='#886393',
    lw=8,
    title=
    f"""{zipcode}'s price over the years from {
        str(ts_df[zipcode].index[0]).split(" ")[0].split("-")[0]} to {
        str(ts_df[zipcode].index[-1]).split(" ")[0].split("-")[0]}"""
);

# %%
with mpl.rc_context():
    mpl.rc('figure', figsize=(15,8))
    mpl.rc('lines', linewidth = 4)
    tsa.seasonal_decompose(ts_df[zipcode].dropna()).plot();

# %%
fn.plot_acf_pacf(ts_df[zipcode].dropna());

# %% [markdown]
# comment

# %%
fn.plot_acf_pacf(ts_df[zipcode].diff(2).dropna());

# %% [markdown]
# comment

# %%
fn.stationarity_check((ts_df[zipcode].diff(1)).diff(12).dropna(), window=4)
# Out:
#             Test Statistic  #Lags Used  ...  p<.05  Stationary?
# ADF Result       -3.905697          15  ...   True         True
#
# [1 rows x 6 columns]

# %% [markdown]
# ### Base MODEL

# %%
## train test split
train_size = 0.8
split_idx = round(len(ts_df[zipcode].dropna()) * train_size)

## Split
train = ts_df[zipcode].dropna().iloc[:split_idx]
test = ts_df[zipcode].dropna().iloc[split_idx:]
# test = ts_df[zipcode].dropna().iloc[len(ts_df[zipcode])-36:]
# train = ts_df[zipcode].dropna().iloc[:len(ts_df[zipcode])-36]

## Visualize the train-test split split
fig, ax = plt.subplots(figsize=(15, 5))
kws = dict(ax=ax, marker='o')
train.plot(**kws, label='train',color='#537d8d')
test.plot(**kws, label='test',color='#ff6961')
ax.legend()
plt.title(f'Visualizing zipcode: {zipcode} Train - Test split')
plt.show()

# %%
# selected params for testing
# time series is not stationary, starting params
p = 0
d = 1
q = 0
# seasonality in data, starting with SARIMAX model
P = 0
D = 1
Q = 0
m = 12

# %%
order = (p,d,q)
seasonal_order = (P,D,Q,m)

# %%
fn.model_builder(train, test, order, seasonal_order, zipcode);
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              11361   No. Observations:                  243
# Model:             SARIMAX(0, 2, 0)x(0, 1, 0, 12)   Log Likelihood               -2174.208
# Date:                            Thu, 17 Jun 2021   AIC                           4350.415
# Time:                                    05:27:45   BIC                           4353.849
# Sample:                                01-31-1996   HQIC                          4351.801
#                                      - 03-31-2016
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2       1.03e+07   5.72e+05     18.003      0.000    9.18e+06    1.14e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.52   Jarque-Bera (JB):               129.26
# Prob(Q):                              0.47   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.36   Skew:                             0.32
# Prob(H) (two-sided):                  0.18   Kurtosis:                         6.62
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """
#                                                                        Model Diagonostics of 11361
#                                                                        Performance on test data of 11361

# %% [markdown]
# Another One

# %%
# selected params for testing
# time series is not stationary, starting params
p = 0
d = 2
q = 0
# seasonality in data, starting with SARIMAX model
P = 0
D = 1
Q = 0
m = 12
order = (p,d,q)
seasonal_order = (P,D,Q,m)
fn.model_builder(train, test, order, seasonal_order, zipcode);
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              11361   No. Observations:                  243
# Model:             SARIMAX(0, 2, 0)x(0, 1, 0, 12)   Log Likelihood               -2174.208
# Date:                            Thu, 17 Jun 2021   AIC                           4350.415
# Time:                                    05:29:08   BIC                           4353.849
# Sample:                                01-31-1996   HQIC                          4351.801
#                                      - 03-31-2016
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2       1.03e+07   5.72e+05     18.003      0.000    9.18e+06    1.14e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.52   Jarque-Bera (JB):               129.26
# Prob(Q):                              0.47   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.36   Skew:                             0.32
# Prob(H) (two-sided):                  0.18   Kurtosis:                         6.62
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """
#                                                                        Model Diagonostics of 11361
#                                                                        Performance on test data of 11361

# %%
from pmdarima.arima.utils import ndiffs
print(ndiffs(ts_df[zipcode],alpha=0.05, test='kpss',max_d=24))
from pmdarima.arima.utils import nsdiffs
print(nsdiffs(ts_df[zipcode],m=12, test='ch',max_D=24))
# Out:
# 1
# 0

# %% [markdown]
# ### grid searching using  pmdarima

# %%
def grid_search(ts, train, test, figsize=(15, 5), trace=True):
    # grid searching using pyramid arima
    d=ndiffs(train, alpha=0.05, test='adf',max_d=4)
    D=nsdiffs(train, m=12, test='ch',max_D=4)
    auto_model = pm.auto_arima(y=train,
                               X=None,
                               start_p=0,
                               d=d,
                               start_q=0,
                               max_p=5,
#                                max_d=12,
                               max_q=5,
                               start_P=0,
                               D=D,
                               start_Q=0,
                               max_P=2,
#                                max_D=12,
                               max_Q=2,
                               max_order=9,
                               m=12,
                               seasonal=True,
                               stationary=False,
                               information_criterion='oob', # 'aic', 'aicc', 'bic', 'hqic', 'oob'
#                                alpha=0.05,
#                                test='adf',
#                                seasonal_test='ch',
                               stepwise=True,
#                                n_jobs=1,
#                                start_params=None,
#                                trend=None, # true-false ## with_intercept
                               method='lbfgs', # ('aic', 'bic', 'hqic','oob')
                               maxiter=100,
#                                offset_test_args=None,
#                                seasonal_test_args=None,
#                                suppress_warnings=True,
                               error_action='trace',
                               trace=2,
#                                random=False,
#                                random_state=None,
#                                n_fits=10,
#                                return_valid_fits=False,
                               out_of_sample_size=6, # 12
                               scoring='mae', # 'mae', 'mse'
                               scoring_args=None,
                               with_intercept="auto")
    # display results of grid search
    display(auto_model.summary())
    auto_model.plot_diagnostics(figsize=figsize)
    plt.tight_layout()
    plt.show()
    # fitting model on train data with the best params found by grid search
    best_model = tsa.SARIMAX(train,
                             order=auto_model.order,
                             seasonal_order=auto_model.seasonal_order,
                             maxiter=500,
                             enforce_invertibility=False).fit()
    forecast = best_model.get_forecast(steps=len(test))
    pred_df_test = pd.DataFrame([
        forecast.conf_int().iloc[:, 0],
        forecast.conf_int().iloc[:, 1], forecast.predicted_mean
    ]).T
    pred_df_test.columns = ["lower", 'upper', 'prediction']
    fn.plot_train_test_pred(train, test, pred_df_test)
    plt.show()

    # fitting on entire data
    best_model_all = tsa.SARIMAX(ts,
                                 order=auto_model.order,
                                 seasonal_order=auto_model.seasonal_order,
                                 maxiter=500,
                                 enforce_invertibility=False).fit()
    forecast = best_model_all.get_forecast(steps=36)
    pred_df = pd.DataFrame([
        forecast.conf_int().iloc[:, 0],
        forecast.conf_int().iloc[:, 1], forecast.predicted_mean
    ]).T
    pred_df.columns = ["lower", 'upper', 'prediction']
    fn.plot_train_test_pred(train, test, pred_df)
    plt.show()
    zipcode = ts.name
    fn.plot_train_test_pred_forecast(train, test, pred_df_test, pred_df, zipcode)

    return auto_model, pred_df

# %%
grid_search(ts_df[zipcode], train, test);
# Out:
# Performing stepwise search to minimize oob
#  ARIMA(0,2,0)(0,0,0)[12]             : OOB=432.667, Time=0.02 sec
# First viable model found (432.667)
#  ARIMA(1,2,0)(1,0,0)[12]             : OOB=444.897, Time=0.13 sec
#  ARIMA(0,2,1)(0,0,1)[12]             : OOB=443.743, Time=0.15 sec
#  ARIMA(0,2,0)(1,0,0)[12]             : OOB=454.467, Time=0.07 sec
#  ARIMA(0,2,0)(0,0,1)[12]             : OOB=446.489, Time=0.18 sec
#  ARIMA(0,2,0)(1,0,1)[12]             : OOB=458.758, Time=0.28 sec
#  ARIMA(1,2,0)(0,0,0)[12]             : OOB=433.404, Time=0.04 sec
#  ARIMA(0,2,1)(0,0,0)[12]             : OOB=433.377, Time=0.05 sec
#  ARIMA(1,2,1)(0,0,0)[12]             : OOB=433.572, Time=0.05 sec
#  ARIMA(0,2,0)(0,0,0)[12] intercept   : OOB=460.616, Time=0.03 sec
#
# Best model:  ARIMA(0,2,0)(0,0,0)[12]
# Total fit time: 0.985 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  243
# Model:               SARIMAX(0, 2, 0)   Log Likelihood               -2153.125
# Date:                Thu, 17 Jun 2021   AIC                           4308.251
# Time:                        08:04:43   BIC                           4311.736
# Sample:                             0   HQIC                          4309.655
#                                 - 243
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      3.415e+06   1.72e+05     19.902      0.000    3.08e+06    3.75e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.24   Jarque-Bera (JB):               235.46
# Prob(Q):                              0.63   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.38   Skew:                            -0.44
# Prob(H) (two-sided):                  0.15   Kurtosis:                         7.76
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """
#   zipcode  mean_forecasted_roi  ...  upper_forecasted_roi  std_forecasted_roi
# 0   11361                -0.92  ...                 54.24               55.17
#
# [1 rows x 5 columns]

# %%
fn.grid_search(ts_df[zipcode], train, test,display_roi_results=True);
# Out:
# Performing stepwise search to minimize oob
#  ARIMA(0,2,0)(0,0,0)[12]             : OOB=315927628.417, Time=0.02 sec
#  ARIMA(1,2,0)(1,0,0)[12]             : OOB=303750511.369, Time=0.09 sec
#  ARIMA(0,2,1)(0,0,1)[12]             : OOB=303923367.325, Time=0.16 sec
#  ARIMA(1,2,0)(0,0,0)[12]             : OOB=315977686.507, Time=0.04 sec
#  ARIMA(1,2,0)(2,0,0)[12]             : OOB=303147866.742, Time=0.27 sec
#  ARIMA(1,2,0)(3,0,0)[12]             : OOB=299557319.568, Time=0.95 sec
#  ARIMA(1,2,0)(3,0,1)[12]             : OOB=297002920.766, Time=0.90 sec
#  ARIMA(1,2,0)(2,0,1)[12]             : OOB=302794016.808, Time=0.45 sec
#  ARIMA(1,2,0)(3,0,2)[12]             : OOB=276748611.160, Time=4.54 sec
#  ARIMA(1,2,0)(2,0,2)[12]             : OOB=inf, Time=1.71 sec
#  ARIMA(1,2,0)(3,0,3)[12]             : OOB=275729700.182, Time=4.55 sec
#  ARIMA(1,2,0)(2,0,3)[12]             : OOB=inf, Time=4.50 sec
#  ARIMA(0,2,0)(3,0,3)[12]             : OOB=269405504.193, Time=4.45 sec
#  ARIMA(0,2,0)(2,0,3)[12]             : OOB=inf, Time=3.91 sec
#  ARIMA(0,2,0)(3,0,2)[12]             : OOB=inf, Time=4.45 sec
#  ARIMA(0,2,0)(2,0,2)[12]             : OOB=inf, Time=2.03 sec
#  ARIMA(0,2,1)(3,0,3)[12]             : OOB=275961513.240, Time=5.18 sec
#  ARIMA(1,2,1)(3,0,3)[12]             : OOB=271918833.420, Time=5.98 sec
#  ARIMA(0,2,0)(3,0,3)[12] intercept   : OOB=252687797.123, Time=5.11 sec
#  ARIMA(0,2,0)(2,0,3)[12] intercept   : OOB=inf, Time=4.43 sec
#  ARIMA(0,2,0)(3,0,2)[12] intercept   : OOB=inf, Time=5.23 sec
#  ARIMA(0,2,0)(2,0,2)[12] intercept   : OOB=297453055.482, Time=0.56 sec
#  ARIMA(1,2,0)(3,0,3)[12] intercept   : OOB=inf, Time=8.23 sec
#  ARIMA(0,2,1)(3,0,3)[12] intercept   : OOB=262997644.494, Time=5.27 sec
#  ARIMA(1,2,1)(3,0,3)[12] intercept   : OOB=228392816.832, Time=5.14 sec
#  ARIMA(1,2,1)(2,0,3)[12] intercept   : OOB=252697067.543, Time=5.11 sec
#  ARIMA(1,2,1)(3,0,2)[12] intercept   : OOB=inf, Time=7.37 sec
#  ARIMA(1,2,1)(2,0,2)[12] intercept   : OOB=inf, Time=2.98 sec
#  ARIMA(2,2,1)(3,0,3)[12] intercept   : OOB=inf, Time=7.87 sec
#  ARIMA(1,2,2)(3,0,3)[12] intercept   : OOB=278775040.774, Time=7.57 sec
#  ARIMA(0,2,2)(3,0,3)[12] intercept   : OOB=283876852.550, Time=6.94 sec
#  ARIMA(2,2,0)(3,0,3)[12] intercept   : OOB=264745802.128, Time=5.67 sec
#  ARIMA(2,2,2)(3,0,3)[12] intercept   : OOB=inf, Time=9.41 sec
#
# Best model:  ARIMA(1,2,1)(3,0,3)[12] intercept
# Total fit time: 131.118 seconds
#                                                                        Model Diagonostics of 11361
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                          SARIMAX Results
# ==================================================================================================
# Dep. Variable:                                          y   No. Observations:                  243
# Model:             SARIMAX(1, 2, 1)x(3, 0, [1, 2, 3], 12)   Log Likelihood               -2150.277
# Date:                                    Thu, 17 Jun 2021   AIC                           4320.554
# Time:                                            08:33:20   BIC                           4355.402
# Sample:                                                 0   HQIC                          4334.594
#                                                     - 243
# Covariance Type:                                      opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     12.8613    532.259      0.024      0.981   -1030.347    1056.069
# ar.L1          0.0232     40.545      0.001      1.000     -79.443      79.490
# ma.L1         -0.0224     40.549     -0.001      1.000     -79.497      79.453
# ar.S.L12       0.6368      0.629      1.013      0.311      -0.595       1.869
# ar.S.L24      -0.5961      0.320     -1.860      0.063      -1.224       0.032
# ar.S.L36       0.6100      0.470      1.298      0.194      -0.311       1.531
# ma.S.L12      -0.6534      0.627     -1.042      0.297      -1.882       0.576
# ma.S.L24       0.6170      0.309      1.995      0.046       0.011       1.223
# ma.S.L36      -0.6221      0.459     -1.354      0.176      -1.523       0.278
# sigma2      2.928e+06      0.108   2.72e+07      0.000    2.93e+06    2.93e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.27   Jarque-Bera (JB):               243.29
# Prob(Q):                              0.60   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.59   Skew:                            -0.42
# Prob(H) (two-sided):                  0.04   Kurtosis:                         7.85
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 9.96e+22. Standard errors may be unstable.
# """
#                                                                        Performance on test data of 11361
#                                                                        Forecast of 11361
#   zipcode  mean_forecasted_roi  ...  upper_forecasted_roi  std_forecasted_roi
# 0   11361                -1.14  ...                 50.25               51.38
#
# [1 rows x 5 columns]

# %% [markdown]
# ## All Zipcodes

# %%
results_, roi_ = fn.model_loop(ts_df,
                               zipcode_list,
                               show_grid_search_steps=False,
                               display_details=False)
# Out:
# Working on #1 out of 55 zipcodes.
# Working on: 11375
# ------------------------------------------------------------------------------------------
# Working on #2 out of 55 zipcodes.
# Working on: 11377
# ------------------------------------------------------------------------------------------
# Working on #3 out of 55 zipcodes.
# Working on: 11355
# ------------------------------------------------------------------------------------------
# Working on #4 out of 55 zipcodes.
# Working on: 11385
# ------------------------------------------------------------------------------------------
# Working on #5 out of 55 zipcodes.
# Working on: 11373
# ------------------------------------------------------------------------------------------
# Working on #6 out of 55 zipcodes.
# Working on: 11372
# ------------------------------------------------------------------------------------------
# Working on #7 out of 55 zipcodes.
# Working on: 11101
# ------------------------------------------------------------------------------------------
# Working on #8 out of 55 zipcodes.
# Working on: 11368
# ------------------------------------------------------------------------------------------
# Working on #9 out of 55 zipcodes.
# Working on: 11354
# ------------------------------------------------------------------------------------------
# Working on #10 out of 55 zipcodes.
# Working on: 11374
# ------------------------------------------------------------------------------------------
# Working on #11 out of 55 zipcodes.
# Working on: 11434
# ------------------------------------------------------------------------------------------
# Working on #12 out of 55 zipcodes.
# Working on: 11691
# ------------------------------------------------------------------------------------------
# Working on #13 out of 55 zipcodes.
# Working on: 11432
# ------------------------------------------------------------------------------------------
# Working on #14 out of 55 zipcodes.
# Working on: 11435
# ------------------------------------------------------------------------------------------
# Working on #15 out of 55 zipcodes.
# Working on: 11103
# ------------------------------------------------------------------------------------------
# Working on #16 out of 55 zipcodes.
# Working on: 11365
# ------------------------------------------------------------------------------------------
# Working on #17 out of 55 zipcodes.
# Working on: 11367
# ------------------------------------------------------------------------------------------
# Working on #18 out of 55 zipcodes.
# Working on: 11357
# ------------------------------------------------------------------------------------------
# Working on #19 out of 55 zipcodes.
# Working on: 11364
# ------------------------------------------------------------------------------------------
# Working on #20 out of 55 zipcodes.
# Working on: 11358
# ------------------------------------------------------------------------------------------
# Working on #21 out of 55 zipcodes.
# Working on: 11104
# ------------------------------------------------------------------------------------------
# Working on #22 out of 55 zipcodes.
# Working on: 11379
# ------------------------------------------------------------------------------------------
# Working on #23 out of 55 zipcodes.
# Working on: 11413
# ------------------------------------------------------------------------------------------
# Working on #24 out of 55 zipcodes.
# Working on: 11420
# ------------------------------------------------------------------------------------------
# Working on #25 out of 55 zipcodes.
# Working on: 11414
# ------------------------------------------------------------------------------------------
# Working on #26 out of 55 zipcodes.
# Working on: 11412
# ------------------------------------------------------------------------------------------
# Working on #27 out of 55 zipcodes.
# Working on: 11361
# ------------------------------------------------------------------------------------------
# Working on #28 out of 55 zipcodes.
# Working on: 11378
# ------------------------------------------------------------------------------------------
# Working on #29 out of 55 zipcodes.
# Working on: 11421
# ------------------------------------------------------------------------------------------
# Working on #30 out of 55 zipcodes.
# Working on: 11419
# ------------------------------------------------------------------------------------------
# Working on #31 out of 55 zipcodes.
# Working on: 11433
# ------------------------------------------------------------------------------------------
# Working on #32 out of 55 zipcodes.
# Working on: 11360
# ------------------------------------------------------------------------------------------
# Working on #33 out of 55 zipcodes.
# Working on: 11418
# ------------------------------------------------------------------------------------------
# Working on #34 out of 55 zipcodes.
# Working on: 11415
# ------------------------------------------------------------------------------------------
# Working on #35 out of 55 zipcodes.
# Working on: 11423
# ------------------------------------------------------------------------------------------
# Working on #36 out of 55 zipcodes.
# Working on: 11369
# ------------------------------------------------------------------------------------------
# Working on #37 out of 55 zipcodes.
# Working on: 11694
# ------------------------------------------------------------------------------------------
# Working on #38 out of 55 zipcodes.
# Working on: 11422
# ------------------------------------------------------------------------------------------
# Working on #39 out of 55 zipcodes.
# Working on: 11417
# ------------------------------------------------------------------------------------------
# Working on #40 out of 55 zipcodes.
# Working on: 11427
# ------------------------------------------------------------------------------------------
# Working on #41 out of 55 zipcodes.
# Working on: 11692
# ------------------------------------------------------------------------------------------
# Working on #42 out of 55 zipcodes.
# Working on: 11370
# ------------------------------------------------------------------------------------------
# Working on #43 out of 55 zipcodes.
# Working on: 11356
# ------------------------------------------------------------------------------------------
# Working on #44 out of 55 zipcodes.
# Working on: 11429
# ------------------------------------------------------------------------------------------
# Working on #45 out of 55 zipcodes.
# Working on: 11362
# ------------------------------------------------------------------------------------------
# Working on #46 out of 55 zipcodes.
# Working on: 11411
# ------------------------------------------------------------------------------------------
# Working on #47 out of 55 zipcodes.
# Working on: 11426
# ------------------------------------------------------------------------------------------
# Working on #48 out of 55 zipcodes.
# Working on: 11428
# ------------------------------------------------------------------------------------------
# Working on #49 out of 55 zipcodes.
# Working on: 11693
# ------------------------------------------------------------------------------------------
# Working on #50 out of 55 zipcodes.
# Working on: 11004
# ------------------------------------------------------------------------------------------
# Working on #51 out of 55 zipcodes.
# Working on: 11416
# ------------------------------------------------------------------------------------------
# Working on #52 out of 55 zipcodes.
# Working on: 11436
# ------------------------------------------------------------------------------------------
# Working on #53 out of 55 zipcodes.
# Working on: 11366
# ------------------------------------------------------------------------------------------
# Working on #54 out of 55 zipcodes.
# Working on: 11363
# ------------------------------------------------------------------------------------------
# Working on #55 out of 55 zipcodes.
# Working on: 11430
# ------------------------------------------------------------------------------------------
# Looping completed.

# %%
import joblib

# %%
# filename='model'
# joblib.dump({'Results':results_, 'ROI': roi_}, f'./model/{filename}.joblib')

# %%
lod = joblib.load('./model/model.joblib')

# %%
results_ = lod['Results']
roi_ = lod['ROI']

# %%
roi_
# Out:
#    zipcode  mean_forecasted_roi  ...  upper_forecasted_roi  std_forecasted_roi
# 0    11375            -0.407783  ...              0.351431            0.759214
# 1    11377             0.071494  ...              0.459602            0.388108
# 2    11355            -0.028766  ...              0.801933            0.830699
# 3    11385             0.121669  ...              0.598945            0.477276
# 4    11373             0.143560  ...              0.594031            0.450472
# 5    11372             0.091835  ...              0.992918            0.901084
# 6    11101            -0.234924  ...              0.494582            0.729505
# 7    11368            -0.081873  ...              0.564025            0.645897
# 8    11354            -0.171130  ...              0.226872            0.398002
# 9    11374             0.026144  ...              0.538047            0.511903
# 10   11434             0.020170  ...              1.040744            1.020574
# 11   11691             0.119483  ...              0.889469            0.769986
# 12   11432             0.106193  ...              0.560677            0.454483
# 13   11435             0.066586  ...              0.668056            0.601470
# 14   11103             0.029160  ...              0.345079            0.315918
# 15   11365             0.054553  ...              0.449217            0.394664
# 16   11367             0.024219  ...              0.473654            0.449436
# 17   11357             0.056442  ...              0.385777            0.329335
# 18   11364            -0.080053  ...              0.339616            0.419669
# 19   11358            -0.029923  ...              0.479078            0.509001
# 20   11104            -0.170688  ...              0.842308            1.012996
# 21   11379             0.077535  ...              0.491638            0.414103
# 22   11413             0.233152  ...              0.761174            0.528022
# 23   11420             0.120723  ...              0.592641            0.471918
# 24   11414             0.113436  ...              0.828422            0.714986
# 25   11412             0.213434  ...              0.730108            0.516674
# 26   11361            -0.011352  ...              0.502473            0.513825
# 27   11378             0.010318  ...              0.439215            0.428897
# 28   11421             0.025506  ...              0.641393            0.615887
# 29   11419             0.236436  ...              0.857163            0.620727
# 30   11433             0.163330  ...              0.889876            0.726545
# 31   11360            -0.098467  ...              0.488047            0.586514
# 32   11418             0.137463  ...              0.716939            0.579476
# 33   11415            -0.710355  ...              0.079759            0.790114
# 34   11423             0.395479  ...              0.876530            0.481051
# 35   11369             0.314395  ...              0.853641            0.539246
# 36   11694             0.177927  ...              0.971021            0.793095
# 37   11422             0.033030  ...              0.562930            0.529901
# 38   11417             0.185645  ...              0.669232            0.483586
# 39   11427             0.305586  ...              0.781134            0.475548
# 40   11692             0.345505  ...              1.600674            1.255169
# 41   11370             0.018441  ...              0.383022            0.364581
# 42   11356             0.160726  ...              0.746317            0.585591
# 43   11429             0.222304  ...              0.672318            0.450014
# 44   11362             0.017091  ...              0.707630            0.690539
# 45   11411             0.050557  ...              0.551162            0.500605
# 46   11426             0.138781  ...              0.614276            0.475495
# 47   11428             0.342410  ...              0.815281            0.472871
# 48   11693             0.000000  ...              0.101486            0.101486
# 49   11004             0.285219  ...              1.008253            0.723034
# 50   11416             0.145932  ...              0.664141            0.518209
# 51   11436             0.043714  ...              0.648198            0.604484
# 52   11366            -0.010804  ...              0.356765            0.367569
# 53   11363            -0.065688  ...              2.182392            2.248081
# 54   11430             0.063997  ...              0.631070            0.567073
#
# [55 rows x 5 columns]

# %% [markdown]
# ## Best Zipcodes

# %%
((roi_.set_index('zipcode')[[
    'mean_forecasted_roi', 'std_forecasted_roi'
]].sort_values(by='mean_forecasted_roi')[-15:].sort_values(
    by='std_forecasted_roi')[:5]) * 100)
# Out:
#          mean_forecasted_roi  std_forecasted_roi
# zipcode
# 11429              22.230379           45.001385
# 11428              34.241021           47.287097
# 11427              30.558596           47.554807
# 11423              39.547861           48.105119
# 11417              18.564516           48.358635

# %%
((roi_.set_index('zipcode')[[
    'mean_forecasted_roi', 'std_forecasted_roi'
]].sort_values(by='mean_forecasted_roi',ascending=True)[-15:].sort_values(
    by='std_forecasted_roi',ascending=False)[-5:]) * 100).sort_values(by='mean_forecasted_roi',ascending=True).plot(kind='barh',figsize=(15,5))
plt.legend(bbox_to_anchor=(1,1), loc="upper left");

# %%
best_investments = ((roi_.set_index('zipcode')[[
    'mean_forecasted_roi', 'std_forecasted_roi'
]].sort_values(by='mean_forecasted_roi')[-15:].sort_values(
    by='std_forecasted_roi')[:5]) * 100).index

best_investments
# Out:
# Index(['11429', '11428', '11427', '11423', '11417'], dtype='object', name='zipcode')

# %%
#############################  OUTPUT CONTROL  ##############################
#############################################################################
show_model_performance = True  # Performance metrics & Diagonistics plots
show_train_fit = True          # test and prediction fit
show_prediction = True         # forecast in the future
#---------------------------------------------------------------------------#
show_detailed_prediction = True  # forecast in the future, whith prediction #
#terminology: ###  prediction is to judge model performance   ###############
###################################   &   ###################################
################   forecast is prediction of unknown  #######################
#############################################################################
for best_zipcode in best_investments:
    # display models
    print(f'{"-"*157}')
    print('\033[1m \033[5;30;47m' +
          f'{" "*70}Report of {best_zipcode}{" "*70}' + '\033[0m')
    print(f'{"-"*157}')
    print('\033[1m \033[91m' + 'Model Used:')
    display(results_[best_zipcode]['model'])
    if show_model_performance:
        # model performance
        print(results_[best_zipcode]['model'].summary())
        results_[best_zipcode]['model'].plot_diagnostics(figsize=(10, 5))
        plt.tight_layout()
    # extracting information from results dict
    train = results_[best_zipcode]['train']
    test = results_[best_zipcode]['test']
    pred_df_test = results_[best_zipcode]['pred_df_test']
    pred_df = results_[best_zipcode]['pred_df']
    if show_train_fit:
        # plot train fit
        _, ax = fn.plot_test_pred(test, pred_df_test)
        ax.set_title(f'test-pred plot of {best_zipcode} [prediction reliability]',
                     size=15)
        plt.show()
    if show_prediction:
        # plot_train_test_pred
        _, ax = fn.plot_train_test_pred(train, test, pred_df)
        ax.set_title(f'train-test-pred plot of {best_zipcode} [forecast]',
                     size=15)
        plt.show()
    if show_detailed_prediction:
        print('\033[1m \033[1;33;40m' + 'Insights:')
        # train_test_pred_forecast
        fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15, 5))
        ax1 = tsa.seasonal_decompose(results_['11432']['test']).trend.plot(
            title='Most recent trend', ax=ax1)
        ax2 = tsa.seasonal_decompose(
            results_['11432']['test'][-36:]).seasonal.plot(
                title='Last three year seasonality', ax=ax2)
        plt.show()
        print('\033[1m \033[1;33;40m' + 'Overall model performance and projected ROI:')
        _, ax, _ = fn.plot_train_test_pred_forecast(train, test, pred_df_test,
                                                    pred_df, best_zipcode)
        ax.set_title(f'train-test-pred-forecast plot of {best_zipcode}',
                     size=15)
    plt.show()
# Out:
# -------------------------------------------------------------------------------------------------------------------------------------------------------------
#                                                                        Report of 11429
# -------------------------------------------------------------------------------------------------------------------------------------------------------------
#  Model Used:
# ARIMA(order=(3, 2, 1), out_of_sample_size=12, scoring_args={},
#       seasonal_order=(2, 0, 0, 12), suppress_warnings=True)
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                  243
# Model:             SARIMAX(3, 2, 1)x(2, 0, [], 12)   Log Likelihood               -2086.374
# Date:                             Thu, 17 Jun 2021   AIC                           4188.747
# Time:                                     19:36:01   BIC                           4216.626
# Sample:                                          0   HQIC                          4199.979
#                                              - 243
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     15.1934     33.831      0.449      0.653     -51.114      81.501
# ar.L1          0.5644      0.226      2.499      0.012       0.122       1.007
# ar.L2         -0.0104      0.018     -0.575      0.565      -0.046       0.025
# ar.L3         -0.0351      0.015     -2.379      0.017      -0.064      -0.006
# ma.L1         -0.5713      0.231     -2.474      0.013      -1.024      -0.119
# ar.S.L12      -0.0236      0.009     -2.556      0.011      -0.042      -0.006
# ar.S.L24       0.0075      0.022      0.344      0.731      -0.035       0.050
# sigma2       1.41e+06   6.89e+04     20.464      0.000    1.27e+06    1.55e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                  12.57   Jarque-Bera (JB):               158.89
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.37   Skew:                            -0.56
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.81
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#  Insights:
#  Overall model performance and projected ROI:
#   zipcode  mean_forecasted_roi  ...  upper_forecasted_roi  std_forecasted_roi
# 0   11429                22.23  ...                 67.23                45.0
#
# [1 rows x 5 columns]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------
#                                                                        Report of 11428
# -------------------------------------------------------------------------------------------------------------------------------------------------------------
#  Model Used:
# ARIMA(order=(1, 2, 3), out_of_sample_size=12, scoring_args={},
#       seasonal_order=(2, 0, 0, 12), suppress_warnings=True)
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                  243
# Model:             SARIMAX(1, 2, 3)x(2, 0, [], 12)   Log Likelihood               -2108.363
# Date:                             Thu, 17 Jun 2021   AIC                           4232.725
# Time:                                     19:36:02   BIC                           4260.603
# Sample:                                          0   HQIC                          4243.957
#                                              - 243
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     17.4917     40.570      0.431      0.666     -62.024      97.007
# ar.L1          0.5195      0.277      1.873      0.061      -0.024       1.063
# ma.L1         -0.5368      0.286     -1.877      0.061      -1.097       0.024
# ma.L2         -0.0136      0.042     -0.320      0.749      -0.096       0.069
# ma.L3         -0.0292      0.019     -1.528      0.127      -0.067       0.008
# ar.S.L12      -0.0179      0.010     -1.763      0.078      -0.038       0.002
# ar.S.L24       0.0071      0.028      0.256      0.798      -0.047       0.061
# sigma2      1.946e+06   9.74e+04     19.970      0.000    1.75e+06    2.14e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):               160.18
# Prob(Q):                              0.90   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.91   Skew:                            -0.34
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.94
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#  Insights:
#  Overall model performance and projected ROI:
#   zipcode  mean_forecasted_roi  ...  upper_forecasted_roi  std_forecasted_roi
# 0   11428                34.24  ...                 81.53               47.29
#
# [1 rows x 5 columns]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------
#                                                                        Report of 11427
# -------------------------------------------------------------------------------------------------------------------------------------------------------------
#  Model Used:
# ARIMA(order=(1, 2, 3), out_of_sample_size=12, scoring_args={},
#       seasonal_order=(1, 0, 3, 12), suppress_warnings=True)
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  243
# Model:             SARIMAX(1, 2, 3)x(1, 0, 3, 12)   Log Likelihood               -2086.555
# Date:                            Thu, 17 Jun 2021   AIC                           4193.110
# Time:                                    19:36:04   BIC                           4227.958
# Sample:                                         0   HQIC                          4207.149
#                                             - 243
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     11.7728     64.474      0.183      0.855    -114.594     138.139
# ar.L1          0.3847      0.545      0.706      0.480      -0.683       1.453
# ma.L1         -0.3928      0.547     -0.718      0.473      -1.465       0.680
# ma.L2         -0.0099      0.044     -0.225      0.822      -0.096       0.076
# ma.L3         -0.0217      0.018     -1.237      0.216      -0.056       0.013
# ar.S.L12       0.5611      2.261      0.248      0.804      -3.870       4.992
# ma.S.L12      -0.5747      2.260     -0.254      0.799      -5.005       3.855
# ma.S.L24       0.0110      0.052      0.211      0.833      -0.091       0.113
# ma.S.L36      -0.0061      0.027     -0.223      0.823      -0.060       0.047
# sigma2       1.65e+06   8.47e+04     19.472      0.000    1.48e+06    1.82e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.14   Jarque-Bera (JB):               194.94
# Prob(Q):                              0.71   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.20   Skew:                            -0.35
# Prob(H) (two-sided):                  0.43   Kurtosis:                         7.35
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#  Insights:
#  Overall model performance and projected ROI:
#   zipcode  mean_forecasted_roi  ...  upper_forecasted_roi  std_forecasted_roi
# 0   11427                30.56  ...                 78.11               47.55
#
# [1 rows x 5 columns]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------
#                                                                        Report of 11423
# -------------------------------------------------------------------------------------------------------------------------------------------------------------
#  Model Used:
# ARIMA(order=(3, 2, 1), out_of_sample_size=12, scoring_args={},
#       seasonal_order=(0, 0, 1, 12), suppress_warnings=True)
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  243
# Model:             SARIMAX(3, 2, 1)x(0, 0, 1, 12)   Log Likelihood               -2116.675
# Date:                            Thu, 17 Jun 2021   AIC                           4247.351
# Time:                                    19:36:06   BIC                           4271.744
# Sample:                                         0   HQIC                          4257.178
#                                             - 243
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     11.5646     37.425      0.309      0.757     -61.787      84.916
# ar.L1          0.5965      0.314      1.897      0.058      -0.020       1.213
# ar.L2         -0.0115      0.028     -0.418      0.676      -0.065       0.042
# ar.L3         -0.0231      0.021     -1.081      0.280      -0.065       0.019
# ma.L1         -0.6076      0.321     -1.894      0.058      -1.236       0.021
# ma.S.L12      -0.0129      0.009     -1.478      0.139      -0.030       0.004
# sigma2      1.988e+06   1.02e+05     19.399      0.000    1.79e+06    2.19e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.21   Jarque-Bera (JB):               102.79
# Prob(Q):                              0.07   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.36   Skew:                            -0.35
# Prob(H) (two-sided):                  0.18   Kurtosis:                         6.12
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#  Insights:
#  Overall model performance and projected ROI:
#   zipcode  mean_forecasted_roi  ...  upper_forecasted_roi  std_forecasted_roi
# 0   11423                39.55  ...                 87.65               48.11
#
# [1 rows x 5 columns]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------
#                                                                        Report of 11417
# -------------------------------------------------------------------------------------------------------------------------------------------------------------
#  Model Used:
# ARIMA(order=(1, 2, 2), out_of_sample_size=12, scoring_args={},
#       seasonal_order=(2, 0, 0, 12), suppress_warnings=True)
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                  243
# Model:             SARIMAX(1, 2, 2)x(2, 0, [], 12)   Log Likelihood               -2108.641
# Date:                             Thu, 17 Jun 2021   AIC                           4231.282
# Time:                                     19:36:07   BIC                           4255.676
# Sample:                                          0   HQIC                          4241.110
#                                              - 243
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     13.6332     41.435      0.329      0.742     -67.579      94.845
# ar.L1          0.7548      0.377      2.004      0.045       0.017       1.493
# ma.L1         -0.7664      0.383     -1.999      0.046      -1.518      -0.015
# ma.L2         -0.0172      0.015     -1.145      0.252      -0.047       0.012
# ar.S.L12      -0.0190      0.011     -1.683      0.092      -0.041       0.003
# ar.S.L24       0.0097      0.058      0.166      0.868      -0.104       0.124
# sigma2      2.252e+06   1.23e+05     18.376      0.000    2.01e+06    2.49e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                  14.91   Jarque-Bera (JB):               355.59
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.54   Skew:                            -0.59
# Prob(H) (two-sided):                  0.05   Kurtosis:                         8.83
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#  Insights:
#  Overall model performance and projected ROI:
#   zipcode  mean_forecasted_roi  ...  upper_forecasted_roi  std_forecasted_roi
# 0   11417                18.56  ...                 66.92               48.36
#
# [1 rows x 5 columns]

# %%
import plotly.express as px

# %%
px.choropleth_mapbox(

# %%
## Viz

# %%
code_match = pd.read_csv('./data/nyc-zip-codes.txt')
code_match['ZipCode'] = code_match['ZipCode'].astype('str')
roi_viz = pd.merge(roi_, code_match, left_on='zipcode', right_on='ZipCode')
roi_viz.drop(columns=['Borough', 'ZipCode'], inplace=True)
# display(roi_viz)
roi_viz[roi_viz.columns.values[1:-1]] = roi_viz[
    roi_viz.columns.values[1:-1]].apply(lambda x: round(x * 100, 2), axis=1)
# roi_viz

# %%
fn.map_zipcodes_return(roi_viz, plot_style='static')
# # Folium version
# fn.zip_code_map(roi_)

# %% [markdown]
# # Todo:
# - statistical measure of model fit goodness
#     - rmse, mae of test and predict
#     - oob information or aic, bic
# - eda on time series
# - show seasonality plot for best models as eda
# - public facing eda
# - individual eda
# - explore bad rois
# <!-- - train model -->
# <!-- - save model -->
# <!-- - show data of top 5 models. -->
# <!-- - turn on/off process in looping. -->
# <!-- - save test pred -->
# <!-- - save model locally -->
# <!-- - ggplot facecolor -->

# %% [markdown]
# ## Prophet

# %%
try:
    from fbprophet import Prophet
#     from ksadsad import sadsa
except:
    # !pip install fbprophet
    # for troubleshooting: https://facebook.github.io/prophet/docs/installation.html#python
from statsmodels.tools.eval_measures import rmse

# %%
zipcode='11428'

# %%
ts_df[zipcode]
# Out:
# date
# 1996-01-31    210887.0
# 1996-02-29    210338.0
# 1996-03-31    210058.0
# 1996-04-30    209436.0
# 1996-05-31    209332.0
#                 ...
# 2020-12-31    602909.0
# 2021-01-31    608164.0
# 2021-02-28    611535.0
# 2021-03-31    616593.0
# 2021-04-30    623049.0
# Freq: M, Name: 11428, Length: 304, dtype: float64

# %%
ts_proph = ts_df[zipcode]

# %%
ts_proph = ts_proph.reset_index()

# %%
ts_proph.columns = ['ds','y']

# %%
ts_proph
# Out:
#             ds         y
# 0   1996-01-31  210887.0
# 1   1996-02-29  210338.0
# 2   1996-03-31  210058.0
# 3   1996-04-30  209436.0
# 4   1996-05-31  209332.0
# ..         ...       ...
# 299 2020-12-31  602909.0
# 300 2021-01-31  608164.0
# 301 2021-02-28  611535.0
# 302 2021-03-31  616593.0
# 303 2021-04-30  623049.0
#
# [304 rows x 2 columns]

# %%
ts_proph.dtypes
# Out:
# ds    datetime64[ns]
# y            float64
# dtype: object

# %%
ts_proph.plot(x='ds', y='y', figsize=(15, 5))
# Out:
# <AxesSubplot:xlabel='ds'>

# %%
len(ts_proph)
# Out:
# 304

# %%
train = ts_proph.iloc[:len(ts_proph) - 36]
test = ts_proph.iloc[len(ts_proph) - 36:]

# %%
## Visualize the train-test split split
fig, ax = plt.subplots(figsize=(15, 5))
kws = dict(x='ds',y='y', ax=ax, marker='+')
train.plot(**kws, label='train')
test.plot(**kws, label='test')
ax.legend()
plt.title(f'Visualizing zipcode: {zipcode} Train - Test split')
plt.show()

# %%
m = Prophet(interval_width=0.95,
            weekly_seasonality=False,
            daily_seasonality=False,seasonality_mode='additive')
m.add_seasonality(name='monthly', period=30.5, fourier_order=5)
m.fit(train)
future = m.make_future_dataframe(periods=36, freq='MS')
forecast = m.predict(future)

# %%
# forecast.tail()

# %%
ax = forecast[len(ts_proph) - 36:].plot(x='ds',
                                        y='yhat',
                                        label='Pred',
                                        legend=True,
                                        figsize=(15, 6),
                                        color='red')
forecast.iloc[len(ts_proph) - 36:].plot(x='ds',
                                        y='yhat_lower',
                                        ax=ax,
                                        color='g')
forecast.iloc[len(ts_proph) - 36:].plot(x='ds',
                                        y='yhat_upper',
                                        ax=ax,
                                        color='g')
ax.fill_between(x=forecast.iloc[len(ts_proph) - 36:]['ds'].values,
                y1=forecast.iloc[len(ts_proph) - 36:]['yhat_lower'],
                y2=forecast.iloc[len(ts_proph) - 36:]['yhat_upper'],
                color='g',
                alpha=.3)
test.plot(x='ds', y='y', label='True', legend=True, ax=ax, color='k')
# Out:
# <AxesSubplot:xlabel='ds'>

# %%
ax = train.plot(x='ds',
                y='y',
                label='True train',
                legend=True,
                figsize=(18, 8))
test.plot(x='ds', y='y', label='True test', legend=True, ax=ax, color='b')
forecast.plot(x='ds',
              y='yhat',
              label='Pred',
              legend=True,
              color='g',
              ax=ax,
              alpha=.6)
ax.fill_between(x=forecast.iloc[len(ts_proph) - 36:]['ds'].values,
                y1=forecast.iloc[len(ts_proph) - 36:]['yhat_lower'],
                y2=forecast.iloc[len(ts_proph) - 36:]['yhat_upper'],
                color='g',
                alpha=.3)

ax.set_xlim((forecast.iloc[0]['ds'], forecast.iloc[len(ts_proph) - 36]['ds']))
ax.legend(bbox_to_anchor=(1, 1), loc="upper left")
plt.title('How well did the model fit')
plt.show()

# %%
ax = train.plot(x='ds',
                y='y',
                label='True train',
                legend=True,
                figsize=(18, 8))
test.plot(x='ds', y='y', label='True test', legend=True, ax=ax, color='b')
forecast.plot(x='ds',
              y='yhat',
              label='Pred',
              legend=True,
              color='g',
              ax=ax,
              alpha=.6)
ax.fill_between(x=forecast.iloc[len(ts_proph) - 36:]['ds'].values,
                y1=forecast.iloc[len(ts_proph) - 36:]['yhat_lower'],
                y2=forecast.iloc[len(ts_proph) - 36:]['yhat_upper'],
                color='g',
                alpha=.3)

# ax.set_xlim((forecast.iloc[len(ts_proph) - 36]['ds'], forecast.iloc[-1]['ds']))
ax.legend(bbox_to_anchor=(1, 1), loc="upper left")
plt.show()

# %%
with plt.style.context('ggplot'):
    m.plot_components(forecast)

# %%
rmse(forecast.iloc[len(ts_proph) - 36:]['yhat'], test['y'])
# Out:
# 18461.86878802158

# %%
test.mean(numeric_only=True)
# Out:
# y    591781.972222
# dtype: float64

# %%
test.std(numeric_only=True)
# Out:
# y    11367.179322
# dtype: float64

# %%
m = Prophet(interval_width=0.95,
            weekly_seasonality=False,
            daily_seasonality=False,seasonality_mode='multiplicative')
m.add_seasonality(name='monthly', period=30.5, fourier_order=5)
m.fit(ts_proph)
future = m.make_future_dataframe(periods=36, freq='MS')
forecast = m.predict(future)

# %%
ax = train.plot(x='ds',
                y='y',
                label='True train',
                legend=True,
                figsize=(18, 8))
test.plot(x='ds', y='y', label='True test', legend=True, ax=ax, color='b')
forecast.plot(x='ds',
              y='yhat',
              label='Pred',
              legend=True,
              color='g',
              ax=ax,
              alpha=.6)
ax.fill_between(x=forecast.iloc[len(ts_proph) - 36:]['ds'].values,
                y1=forecast.iloc[len(ts_proph) - 36:]['yhat_lower'],
                y2=forecast.iloc[len(ts_proph) - 36:]['yhat_upper'],
                color='g',
                alpha=.3)

# ax.set_xlim((forecast.iloc[len(ts_proph) - 36]['ds'], forecast.iloc[-1]['ds']))
ax.legend(bbox_to_anchor=(1, 1), loc="upper left")
plt.show()

# %% [markdown]
# Not good yet

# %% [markdown]
# ## RNN

# %%
# gluon package
